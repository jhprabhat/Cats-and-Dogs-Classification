# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size = (2, 2)))

classifier.add(Conv2D(64, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(18, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))


# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Part 2 - Fitting the CNN to the images


train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('G:/Document/CNN_Models/Cat_Dogs/Train_Pics',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('G:/Document/CNN_Models/Cat_Dogs/Test_Pics',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 1529 images belonging to 2 classes.
# Found 704 images belonging to 2 classes.

# %%
model = classifier.fit_generator(training_set,
                         epochs =50,
                         validation_data = test_set,
                        verbose=True,
                         validation_steps = 20)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 4s 81ms/step - loss: 0.3626 - accuracy: 0.8352 - val_loss: 0.6772 - val_accuracy: 0.7016
# Epoch 2/50
# 48/48 [==============================] - 4s 81ms/step - loss: 0.3656 - accuracy: 0.8293 - val_loss: 0.6507 - val_accuracy: 0.7109
# Epoch 3/50
# 48/48 [==============================] - 4s 81ms/step - loss: 0.3570 - accuracy: 0.8424 - val_loss: 0.6958 - val_accuracy: 0.7094
# Epoch 4/50
# 48/48 [==============================] - 4s 81ms/step - loss: 0.3587 - accuracy: 0.8319 - val_loss: 0.6598 - val_accuracy: 0.7063
# Epoch 5/50
# 48/48 [==============================] - 4s 84ms/step - loss: 0.3320 - accuracy: 0.8535 - val_loss: 0.7067 - val_accuracy: 0.7141
# Epoch 6/50
# 48/48 [==============================] - 4s 83ms/step - loss: 0.3393 - accuracy: 0.8528 - val_loss: 0.6390 - val_accuracy: 0.7031
# Epoch 7/50
# ...

# %%
classifier.save("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.history
# Out:
# {'loss': [0.36257246136665344,
#   0.3655843734741211,
#   0.356998473405838,
#   0.3586634695529938,
#   0.3319699764251709,
#   0.33933451771736145,
#   0.33578142523765564,
#   0.32795974612236023,
#   0.32647761702537537,
#   0.2954910397529602,
#   0.31170597672462463,
#   0.28392186760902405,
#   0.2922391891479492,
#   0.2705850601196289,
#   0.24915087223052979,
#   0.2701796293258667,
#   0.2519562244415283,
#   0.26187005639076233,
#   0.25984427332878113,
#   0.2687009572982788,
#   0.23528900742530823,
#   0.23187220096588135,
#   0.2182772308588028,
#   0.22771957516670227,
#   0.2221740186214447,
#   0.2141427844762802,
#   0.2067050188779831,
#   0.21653595566749573,
#   0.20427219569683075,
#   0.1753763109445572,
#   0.19390276074409485,
#   0.17520418763160706,
#   0.16892126202583313,
#   0.1673600673675537,
#   0.1589592546224594,
#   0.15160684287548065,
#   0.15595224499702454,
#   0.16589942574501038,
#   0.1689586043357849,
#   0.16270743310451508,
# ...

# %%
# Part 3 - Making new predictions




import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('G:/Document/CNN_Models/Cat_Dogs/cat1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
    print(prediction)
else:
    prediction = 'cat'
    print(prediction)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f49315f41fd9> in <module>
#       9 test_image = image.img_to_array(test_image)
#      10 test_image = np.expand_dims(test_image, axis = 0)
# ---> 11 result = model.predict(test_image)
#      12 training_set.class_indices
#      13 if result[0][0] == 1:
#
# AttributeError: 'History' object has no attribute 'predict'
